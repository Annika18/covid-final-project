# %%
import pandas as pd

# %%
fulldata = pd.read_csv('finaldataset.csv', dtype={'FIPS': str})
fulldata.head()
# Out:
#     FIPS State           Area_name  Rural_urban_continuum_code_2013  \
# 0  01001    AL  Autauga County, AL                              2.0
# 1  01001    AL  Autauga County, AL                              2.0
# 2  01001    AL  Autauga County, AL                              2.0
# 3  01001    AL  Autauga County, AL                              2.0
# 4  01001    AL  Autauga County, AL                              2.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2018  \
# 0                        2.0         1.0                      25957
# 1                        2.0         1.0                      25957
# 2                        2.0         1.0                      25957
# 3                        2.0         1.0                      25957
# 4                        2.0         1.0                      25957
#
#    Employed_2018  Unemployed_2018  Unemployment_rate_2018     ...       \
# 0          25015              942                     3.6     ...
# ...

# %%
data2 = fulldata.drop(['Civilian_labor_force_2018', 'Employed_2018',
                      'Unemployed_2018', 'Med_HH_Income_Percent_of_State_Total_2018',
                      'county', 'state', 'ST', 'COUNTY'], axis=1)

data2.head()
# Out:
#     FIPS State           Area_name  Rural_urban_continuum_code_2013  \
# 0  01001    AL  Autauga County, AL                              2.0
# 1  01001    AL  Autauga County, AL                              2.0
# 2  01001    AL  Autauga County, AL                              2.0
# 3  01001    AL  Autauga County, AL                              2.0
# 4  01001    AL  Autauga County, AL                              2.0
#
#    Urban_influence_code_2013  Metro_2013  Unemployment_rate_2018  \
# 0                        2.0         1.0                     3.6
# 1                        2.0         1.0                     3.6
# 2                        2.0         1.0                     3.6
# 3                        2.0         1.0                     3.6
# 4                        2.0         1.0                     3.6
#
#    Median_Household_Income_2018        date  cases      ...       RPL_THEME2  \
# 0                         59338  2020-03-24      1      ...            0.581
# ...

# %%
data2 = data2[data2.FIPS != '35039']

len(data2)
# Out:
# 116929

# %%
data2.to_csv('finaldataset2.csv', index=False)
